# %%
import requests
import pandas as pd

def get_participants(id) -> any:
    """
    @param id is the reactome id that is going to be grabbed
    @return is the data in json format with all of the participants
    """
    #get the url
    url = 'https://reactome.org/ContentService/data/participants/%s' % id

    #check the response
    response = requests.get(url=url, headers={'accept': 'application/json'})

    #if successful
    if response.status_code == 200:
        #return data
        return response.json()

    #if not successful
    else:
        #get error
        print('Error, Status Code:' % response.status_code)

# %%
#grab the data from metoabolism of protiens->protien repair
data = get_participants('R-HSA-5676934.2')
data
# Out:
# [{'peDbId': 5676580,
#   'displayName': 'PCMT1 [cytosol]',
#   'schemaClass': 'EntityWithAccessionedSequence',
#   'refEntities': [{'identifier': 'P22061',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:P22061 PCMT1',
#     'dbId': 61738,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/P22061'}]},
#  {'peDbId': 71284,
#   'displayName': 'AdoMet [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '15414',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'S-adenosyl-L-methionine [ChEBI:15414]',
#     'dbId': 29392,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:15414'}]},
#  {'peDbId': 5687536,
#   'displayName': 'isoAsp [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '85309',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'isoaspartate [ChEBI:85309]',
#     'dbId': 5685143,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:85309'}]},
#  {'peDbId': 71285,
#   'displayName': 'AdoHcy [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '16680',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'S-adenosyl-L-homocysteine [ChEBI:16680]',
#     'dbId': 29396,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16680'}]},
#  {'peDbId': 5687529,
#   'displayName': 'MetAsp [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '31882',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'N-methyl-D-aspartic acid [ChEBI:31882]',
#     'dbId': 5687527,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:31882'}]},
#  {'peDbId': 5676939,
#   'displayName': 'MSRBs [cytosol]',
#   'schemaClass': 'DefinedSet',
#   'refEntities': [{'identifier': 'Q9Y3D2',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:Q9Y3D2 MSRB2',
#     'dbId': 67726,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/Q9Y3D2'},
#    {'identifier': 'Q8IXL7',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:Q8IXL7 MSRB3',
#     'dbId': 355917,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/Q8IXL7'},
#    {'identifier': 'Q9NZV6',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:Q9NZV6 MSRB1',
#     'dbId': 64294,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/Q9NZV6'}]},
#  {'peDbId': 66000,
#   'displayName': 'TXN [cytosol]',
#   'schemaClass': 'EntityWithAccessionedSequence',
#   'refEntities': [{'identifier': 'P10599',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:P10599 TXN',
#     'dbId': 66001,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/P10599'}]},
#  {'peDbId': 5676932,
#   'displayName': 'L-methionine (R)-S-oxide [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '49032',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine (R)-S-oxide [ChEBI:49032]',
#     'dbId': 5676947,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:49032'}]},
#  {'peDbId': 174390,
#   'displayName': 'L-Met [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '57844',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine zwitterion [ChEBI:57844]',
#     'dbId': 8943622,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:57844'}]},
#  {'peDbId': 73668,
#   'displayName': '2xHC-TXN [cytosol]',
#   'schemaClass': 'EntityWithAccessionedSequence',
#   'refEntities': [{'identifier': 'P10599',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:P10599 TXN',
#     'dbId': 66001,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/P10599'}]},
#  {'peDbId': 29408,
#   'displayName': 'H2O2 [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '16240',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'hydrogen peroxide [ChEBI:16240]',
#     'dbId': 114745,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:16240'}]},
#  {'peDbId': 5676943,
#   'displayName': 'MetO [cytosol]',
#   'schemaClass': 'DefinedSet',
#   'refEntities': [{'identifier': '49032',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine (R)-S-oxide [ChEBI:49032]',
#     'dbId': 5676947,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:49032'},
#    {'identifier': '49031',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine (S)-S-oxide [ChEBI:49031]',
#     'dbId': 5676935,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:49031'}]},
#  {'peDbId': 29356,
#   'displayName': 'H2O [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '15377',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'water [ChEBI:15377]',
#     'dbId': 114728,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:15377'}]},
#  {'peDbId': 5687535,
#   'displayName': 'L-Asp,isoAsp [cytosol]',
#   'schemaClass': 'DefinedSet',
#   'refEntities': [{'identifier': '85309',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'isoaspartate [ChEBI:85309]',
#     'dbId': 5685143,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:85309'},
#    {'identifier': '29991',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-aspartate(1-) [ChEBI:29991]',
#     'dbId': 8943587,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:29991'}]},
#  {'peDbId': 5687524,
#   'displayName': 'L-Arg,L-Asn [cytosol]',
#   'schemaClass': 'DefinedSet',
#   'refEntities': [{'identifier': '58048',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-asparagine zwitterion [ChEBI:58048]',
#     'dbId': 8943583,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:58048'},
#    {'identifier': '32682',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-argininium(1+) [ChEBI:32682]',
#     'dbId': 8943581,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:32682'}]},
#  {'peDbId': 5676963,
#   'displayName': 'MetOO [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '21363',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine sulfone [ChEBI:21363]',
#     'dbId': 5676965,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:21363'}]},
#  {'peDbId': 5676904,
#   'displayName': 'MSRA [cytosol]',
#   'schemaClass': 'EntityWithAccessionedSequence',
#   'refEntities': [{'identifier': 'Q9UJ68',
#     'schemaClass': 'ReferenceGeneProduct',
#     'displayName': 'UniProt:Q9UJ68 MSRA',
#     'dbId': 59599,
#     'icon': 'EntityWithAccessionedSequence',
#     'url': 'http://purl.uniprot.org/uniprot/Q9UJ68'}]},
#  {'peDbId': 5676925,
#   'displayName': 'L-methionine (S)-S-oxide [cytosol]',
#   'schemaClass': 'SimpleEntity',
#   'refEntities': [{'identifier': '49031',
#     'schemaClass': 'ReferenceMolecule',
#     'displayName': 'L-methionine (S)-S-oxide [ChEBI:49031]',
#     'dbId': 5676935,
#     'icon': 'SimpleEntity',
#     'url': 'http://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:49031'}]}]

# %%
def participants_to_csv(json_data) -> any:
    '''
    @param json_data is the data in json
    @return csv_data is the data in csv
    '''
    ReactomeId = []
    displayName = []
    entityType = []
    referenceId = []
    schemaClass = []
    url = []
    headers = ['ReactomeId', 'displayName', 'entityType', 'schemaClass', 'url', 'referenceId']
    
    #parse the data
    for i in json_data:
        for el in i['refEntities']:
            ReactomeId.append(i['peDbId'])
            displayName.append(el['displayName'])
            schemaClass.append(el['icon'])
            url.append(el['url'])
            referenceId.append(el['identifier'])
        
    #get uniprot/chembl id
    for i in range(len(displayName)):

        #check if chembi or uniprot
        if 'ChEBI' in displayName[i]:
            #append type to list
            entityType.append('compound')
            #cut out chembI from name
            index = displayName[i].index('ChEBI')
            displayName[i] = displayName[i][0:index - 2]

        elif 'UniProt' in displayName[i]:
            #append type to list
            entityType.append('protein')
            displayName[i] = displayName[i].split()
            displayName[i] = displayName[i][1]


    #create dataframe
    df = {headers[0] : ReactomeId, headers[1] : displayName, headers[2] : entityType, headers[3] : schemaClass, headers[4] : url, headers[5] : referenceId}
    df = pd.DataFrame(df)
    return df

# %%
df = participants_to_csv(data)
df
# Out:
#     ReactomeId                displayName entityType  \
# 0      5676580                      PCMT1    protein
# 1        71284    S-adenosyl-L-methionine   compound
# 2      5687536               isoaspartate   compound
# 3        71285  S-adenosyl-L-homocysteine   compound
# 4      5687529   N-methyl-D-aspartic acid   compound
# 5      5676939                      MSRB2    protein
# 6      5676939                      MSRB3    protein
# 7      5676939                      MSRB1    protein
# 8        66000                        TXN    protein
# 9      5676932   L-methionine (R)-S-oxide   compound
# 10      174390    L-methionine zwitterion   compound
# 11       73668                        TXN    protein
# 12       29408          hydrogen peroxide   compound
# 13     5676943   L-methionine (R)-S-oxide   compound
# 14     5676943   L-methionine (S)-S-oxide   compound
# 15       29356                      water   compound
# 16     5687535               isoaspartate   compound
# 17     5687535            L-aspartate(1-)   compound
# 18     5687524    L-asparagine zwitterion   compound
# 19     5687524           L-argininium(1+)   compound
# 20     5676963       L-methionine sulfone   compound
# 21     5676904                       MSRA    protein
# 22     5676925   L-methionine (S)-S-oxide   compound
#
#                       schemaClass  \
# 0   EntityWithAccessionedSequence
# 1                    SimpleEntity
# 2                    SimpleEntity
# 3                    SimpleEntity
# 4                    SimpleEntity
# 5   EntityWithAccessionedSequence
# 6   EntityWithAccessionedSequence
# 7   EntityWithAccessionedSequence
# 8   EntityWithAccessionedSequence
# 9                    SimpleEntity
# 10                   SimpleEntity
# 11  EntityWithAccessionedSequence
# 12                   SimpleEntity
# 13                   SimpleEntity
# 14                   SimpleEntity
# 15                   SimpleEntity
# 16                   SimpleEntity
# 17                   SimpleEntity
# 18                   SimpleEntity
# 19                   SimpleEntity
# 20                   SimpleEntity
# 21  EntityWithAccessionedSequence
# 22                   SimpleEntity
#
#                                                   url referenceId
# 0              http://purl.uniprot.org/uniprot/P22061      P22061
# 1   http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       15414
# 2   http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       85309
# 3   http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       16680
# 4   http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       31882
# 5              http://purl.uniprot.org/uniprot/Q9Y3D2      Q9Y3D2
# 6              http://purl.uniprot.org/uniprot/Q8IXL7      Q8IXL7
# 7              http://purl.uniprot.org/uniprot/Q9NZV6      Q9NZV6
# 8              http://purl.uniprot.org/uniprot/P10599      P10599
# 9   http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       49032
# 10  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       57844
# 11             http://purl.uniprot.org/uniprot/P10599      P10599
# 12  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       16240
# 13  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       49032
# 14  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       49031
# 15  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       15377
# 16  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       85309
# 17  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       29991
# 18  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       58048
# 19  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       32682
# 20  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       21363
# 21             http://purl.uniprot.org/uniprot/Q9UJ68      Q9UJ68
# 22  http://www.ebi.ac.uk/chebi/searchId.do?chebiId...       49031
