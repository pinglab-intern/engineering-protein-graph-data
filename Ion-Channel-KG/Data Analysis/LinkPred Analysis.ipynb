# %%
from neo4j import GraphDatabase 
import pandas as pd
from tqdm import tqdm
import ast

url = "bolt://localhost:7687" 

driver = GraphDatabase.driver(url, auth=("neo4j", "heart"))

# %% [markdown]
# # Graph Algorithms

# %% [markdown]
# Creating in-memory graph with cypher projection:
#
# @cypher:
#
#     CALL gds.graph.create(
#     'OS KG',
#         ["MeSH", "Protein", "Document", "Drug"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'}
#         }
#     )

# %%
def count_nodes():
    query = "MATCH (n) RETURN COUNT(n)"
    with driver.session() as session:
        info = session.run(query)
    return info

count_nodes()

# %% [markdown]
# # Node Similarity for OS and CVD

# %% [markdown]
# Creating in-memory graph with cypher projection:
#
# USED IN CLASS:
#
# @cypher:
#
#     CALL gds.graph.create(
#     'MeSH-PMID-Protein-Drug',
#         ["MeSH", "Document", "Protein", "Drug"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'}
#         }
#     )
#
# UNUSED:
#
# @cypher:
#
#     CALL gds.graph.create(
#     'OS KG',
#         ["MeSH", "Protein", "Document", "Drug"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'}
#         }
#     )
#
#     CALL gds.graph.create(
#     'MESH',
#         ["MeSH"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'}
#         }
#     )
#
#     CALL gds.graph.create(
#     'MeSH-PMID-Protein',
#         ["MeSH", "Document", "Protein"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'}
#         }
#     )

# %%
class nodesim():
    """Class to run LinkPred"""
    def __init__(self) -> None:
        self.driver = GraphDatabase.driver("neo4j://localhost:7687", auth=("neo4j", "heart"))

    def close(self) -> None:
        self.driver.close()

    @classmethod
    def algo(cls, tx) -> any:
        """
        @param cls is the class
        @param tx is the transaction
        @return result.data() is the data of the cluster
        """
        query = ("""
        CALL gds.nodeSimilarity.stream('MeSH-PMID-Protein-Drug')
        YIELD node1, node2, similarity
        RETURN gds.util.asNode(node1).name AS MeSH_Term1, gds.util.asNode(node1).type AS Type1, similarity, gds.util.asNode(node2).type AS Type2, gds.util.asNode(node2).name AS MeSH_Term2
        ORDER BY similarity DESCENDING, MeSH_Term1, MeSH_Term2
        """)
        result = tx.run(query)
        return result.data()


    def run_algo(self) -> any:
        """
        @param self
        @return result is the dataframe from the pagerank
        """
        result = self.driver.session().write_transaction(self.algo)
        result = pd.DataFrame(result)
        return result

# %%
#3 min runtime
algo = nodesim()
result = algo.run_algo()
#extract nodes whose similarity is 1
types = ["OS", "CVD"]
CVD_OS = result[result["Type1"].isin(types)]
CVD_OS = CVD_OS[result["Type2"].isin(types)]
#result.dropna()
CVD_OS = CVD_OS.reset_index(drop=True)
CVD_OS
# Out:
# <ipython-input-103-9f86dde735ed>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   CVD_OS = CVD_OS[result["Type2"].isin(types)]
#                                        MeSH_Term1 Type1  similarity Type2  \
# 0                                brugada syndrome   CVD    0.321839   CVD
# 1               cardiac conduction system disease   CVD    0.321839   CVD
# 2                            dna-binding proteins    OS    0.251169    OS
# 3                           transcription factors    OS    0.251169    OS
# 4                   bicuspid aortic valve disease   CVD    0.227848   CVD
# ...                                           ...   ...         ...   ...
# 1453  tachycardia, atrioventricular nodal reentry   CVD    0.000364   CVD
# 1454    protein disulfide reductase (glutathione)    OS    0.000323    OS
# 1455                 aortic stenosis, subvalvular   CVD    0.000161    OS
# 1456            glycogen storage disease type iib   CVD    0.000161    OS
# 1457                          heterotaxy syndrome   CVD    0.000161    OS
#
#                              MeSH_Term2
# 0     cardiac conduction system disease
# 1                      brugada syndrome
# 2                 transcription factors
# 3                  dna-binding proteins
# 4                  heart valve diseases
# ...                                 ...
# 1453              myocardial infarction
# 1454                  membrane proteins
# 1455                  membrane proteins
# 1456                  membrane proteins
# 1457                  membrane proteins
#
# [1458 rows x 5 columns]

# %%
#filtering out CVD and OS to compare them:
compare = CVD_OS[CVD_OS["Type1"] != CVD_OS["Type2"]].reset_index(drop=True)
compare.head()
compare
# Out:
#                                      MeSH_Term1 Type1  similarity Type2  \
# 0                               malondialdehyde    OS    0.030755   CVD
# 1                 myocardial reperfusion injury   CVD    0.030755    OS
# 2                 myocardial reperfusion injury   CVD    0.021693    OS
# 3                                    isoenzymes    OS    0.021073   CVD
# 4           anterior wall myocardial infarction   CVD    0.016667    OS
# 5                               lipid peroxides    OS    0.016667   CVD
# 6                  cardiomyopathy, hypertrophic   CVD    0.013499    OS
# 7                     diabetic cardiomyopathies   CVD    0.010870    OS
# 8                         protein carbonylation    OS    0.010870   CVD
# 9                                deoxyguanosine    OS    0.009804   CVD
# 10                      ventricular dysfunction   CVD    0.009804    OS
# 11                      ventricular dysfunction   CVD    0.008403    OS
# 12               aortic stenosis, supravalvular   CVD    0.008197    OS
# 13                          coronary restenosis   CVD    0.008197    OS
# 14                     fatty acids, unsaturated    OS    0.008197   CVD
# 15              nad(p)h dehydrogenase (quinone)    OS    0.008197   CVD
# 16                                    melatonin    OS    0.008000   CVD
# 17                          coronary restenosis   CVD    0.007752    OS
# 18                            peroxiredoxin iii    OS    0.007634   CVD
# 19                    cardiomyopathy, alcoholic   CVD    0.006944    OS
# 20                                 homocysteine    OS    0.006944   CVD
# 21                                 homocysteine    OS    0.006944   CVD
# 22              procollagen-proline dioxygenase    OS    0.006494   CVD
# 23                               edema, cardiac   CVD    0.006452    OS
# 24                                 homocysteine    OS    0.006452   CVD
# 25                                 homocysteine    OS    0.006329   CVD
# 26                                 homocysteine    OS    0.005682   CVD
# 27                                    melatonin    OS    0.005230   CVD
# 28                            peroxiredoxin iii    OS    0.005155   CVD
# 29                              epoxy compounds    OS    0.005076   CVD
# 30                              epoxy compounds    OS    0.004566   CVD
# 31                        cardio-renal syndrome   CVD    0.004444    OS
# 32                            digeorge syndrome   CVD    0.003568    OS
# 33                            peroxiredoxin iii    OS    0.003155   CVD
# 34                               edema, cardiac   CVD    0.002710    OS
# 35                        chagas cardiomyopathy   CVD    0.002506    OS
# 36                          heterotaxy syndrome   CVD    0.001992    OS
# 37                      thioredoxin reductase 2    OS    0.001887   CVD
# 38                               barth syndrome   CVD    0.001855    OS
# 39              thioredoxin-disulfide reductase    OS    0.001852   CVD
# 40                                glutaredoxins    OS    0.001698   CVD
# 41                            peroxiredoxin iii    OS    0.001695   CVD
# 42          anterior wall myocardial infarction   CVD    0.001393    OS
# 43              methionine sulfoxide reductases    OS    0.001323   CVD
# 44                             nitrogen dioxide    OS    0.001323   CVD
# 45                                 tocotrienols    OS    0.001253   CVD
# 46                             nitrogen dioxide    OS    0.001217   CVD
# 47                            digeorge syndrome   CVD    0.001088    OS
# 48                            digeorge syndrome   CVD    0.000919    OS
# 49                                 pericarditis   CVD    0.000678    OS
# 50                          sarcoglycanopathies   CVD    0.000619    OS
# 51                      thioredoxin reductase 2    OS    0.000528   CVD
# 52                          sarcoglycanopathies   CVD    0.000483    OS
# 53                          heterotaxy syndrome   CVD    0.000463    OS
# 54  tachycardia, atrioventricular nodal reentry   CVD    0.000462    OS
# 55                          sarcoglycanopathies   CVD    0.000398    OS
# 56              methionine sulfoxide reductases    OS    0.000364   CVD
# 57                 aortic stenosis, subvalvular   CVD    0.000161    OS
# 58            glycogen storage disease type iib   CVD    0.000161    OS
# 59                          heterotaxy syndrome   CVD    0.000161    OS
#
#                              MeSH_Term2
# 0         myocardial reperfusion injury
# 1                       malondialdehyde
# 2                  superoxide dismutase
# 3                 myocardial infarction
# 4                       lipid peroxides
# 5   anterior wall myocardial infarction
# 6                      carrier proteins
# 7                 protein carbonylation
# 8             diabetic cardiomyopathies
# 9               ventricular dysfunction
# 10                       deoxyguanosine
# 11                         thioredoxins
# 12             fatty acids, unsaturated
# 13      nad(p)h dehydrogenase (quinone)
# 14       aortic stenosis, supravalvular
# 15                  coronary restenosis
# 16             ventricular fibrillation
# 17                      lipid peroxides
# 18                      angina pectoris
# 19                         homocysteine
# 20            cardiomyopathy, alcoholic
# 21        hypertrophy, left ventricular
# 22            diabetic cardiomyopathies
# 23                         homocysteine
# 24                       edema, cardiac
# 25                     coronary disease
# 26        bicuspid aortic valve disease
# 27        myocardial reperfusion injury
# 28                     angina, unstable
# 29                      angina pectoris
# 30                aortic valve stenosis
# 31                            melatonin
# 32                     nuclear proteins
# 33               death, sudden, cardiac
# 34                      malondialdehyde
# 35                      malondialdehyde
# 36                             cysteine
# 37        ventricular dysfunction, left
# 38                transcription factors
# 39        ventricular dysfunction, left
# 40                         cardiomegaly
# 41              cardiomyopathy, dilated
# 42                    hydrogen peroxide
# 43        myocardial reperfusion injury
# 44                  atrial fibrillation
# 45                  myocardial ischemia
# 46                  myocardial ischemia
# 47                  cell cycle proteins
# 48                transcription factors
# 49                           isoenzymes
# 50                 dna-binding proteins
# 51                        heart failure
# 52                    membrane proteins
# 53                transcription factors
# 54                transcription factors
# 55                     carrier proteins
# 56                myocardial infarction
# 57                    membrane proteins
# 58                    membrane proteins
# 59                    membrane proteins

# %%
#compare.to_csv("OS_CVD_Nodesim.csv")

# %% [markdown]
# # Link Prediction between OS and CVD

# %% [markdown]
# @cypher:
#
#     CALL gds.graph.create(
#     'stuff' ,
#         ["MeSH", "Document", "Protein", "Drug", "Pathway"],
#         {
#             MENTIONS: {orientation: 'UNDIRECTED'},
#             TARGET: {orientation: 'UNDIRECTED'},
#             ASSIGNS: {orientation: 'UNDIRECTED'},
#             CANDIDATE: {orientation: 'UNDIRECTED'}
#         }
#     )

# %%
#GET A LIST OF ALL OS NODES
type = "OS"
query = "MATCH (m:MeSH{type: '" + type + "'}) RETURN m.name as Name, m.event as Event"
Result = []
with driver.session() as session:
    info = session.run(query)
    for item in info:
        Result.append({"OS Name":item.values()[0],
                      "OS Event":item.values()[1]})

OS = pd.DataFrame(Result)
OS
# Out:
#                   OS Name OS Event
# 0             superoxides      IOS
# 1       hydrogen peroxide      IOS
# 2        hydroxyl radical      IOS
# 3          singlet oxygen      IOS
# 4               peroxides      IOS
# ..                    ...      ...
# 73            zeaxanthins      ROS
# 74               lycopene      ROS
# 75  protein carbonylation      OOS
# 76          hydroxylation      OOS
# 77         deoxyguanosine      OOS
#
# [78 rows x 2 columns]

# %%
#GET A LIST OF ALL CVD NODES
type = "CVD"
query = "MATCH (m:MeSH{type: '" + type + "'}) RETURN m.name as Name, m.category as Event"
Result = []
with driver.session() as session:
    info = session.run(query)
    for item in info:
        Result.append({"CVD Name":item.values()[0],
                      "CVD Category":item.values()[1]})

CVD = pd.DataFrame(Result)
CVD
# Out:
#                                        CVD Name CVD Category
# 0                              cardiomyopathies           CM
# 1    arrhythmogenic right ventricular dysplasia          CHD
# 2                     cardiomyopathy, alcoholic           CM
# 3                       cardiomyopathy, dilated          OHD
# 4                  cardiomyopathy, hypertrophic           VD
# ..                                          ...          ...
# 171             cardiac papillary fibroelastoma          OHD
# 172                              carney complex          OHD
# 173                                pericarditis          OHD
# 174                  pericarditis, constrictive          OHD
# 175                   pericarditis, tuberculous          OHD
#
# [176 rows x 2 columns]

# %%
class LinkPred():
    """Class to run LinkPred"""
    def __init__(self) -> None:
        self.driver = GraphDatabase.driver("neo4j://localhost:7687", auth=("neo4j", "heart"))

    def close(self) -> None:
        self.driver.close()

    @classmethod
    def LinkPred(cls, tx, name1, name2) -> any:
        """
        @param cls is the class
        @param tx is the transaction
        @return result.data() is the data of the cluster
        """
        query = ("""
        MATCH (m:MeSH{name: $name1})
        MATCH (n:MeSH{name: $name2})
        RETURN gds.alpha.linkprediction.commonNeighbors(n, m) AS LinkPred_Score
        """)
        result = tx.run(query, name1 = name1, name2 = name2)
        return result.data()

    def run_LinkPred(self, df1 = OS, df2 = CVD) -> any:
        """
        @param self
        @param df1 is first df comparing
        @param df2 is second df comparing
        @return result is the dataframe from the pagerank
        """
        # create empty list
        df = pd.DataFrame()
        linkpred = []
        os = []
        cvd = []
        os_event = []
        cvd_cat = []
        for i in tqdm(range(len(df1['OS Name'])), desc= "Iterating: "):
            for j in range(len(df2["CVD Name"])):
                linkpred.append(self.driver.session().write_transaction(self.LinkPred, df1['OS Name'][i], df2['CVD Name'][j]))
                os.append(df1['OS Name'][i])
                cvd.append(df2['CVD Name'][j])
                os_event.append(df1["OS Event"][i])
                cvd_cat.append(df2["CVD Category"][j])                
        df["CVD Name"] = cvd
        df["CVD Category"] = cvd_cat
        df["LinkPred Score"] = linkpred
        df["OS Event"] = os_event
        df["OS Name"] = os
        return df

# %%
#3 min runtime
pred = LinkPred()
df = pred.run_LinkPred(OS, CVD)
# Out:
# Iterating: 100%|██████████| 78/78 [00:46<00:00,  1.66it/s]

# %%
for index, row in df.iterrows():
    row['LinkPred Score'] = row['LinkPred Score'][0]['LinkPred_Score']
df = df.sort_values(by = 'LinkPred Score', ascending= False)
df = df.reset_index(drop = True)
df = df[df["LinkPred Score"] != 0]
df
# Out:
#                                 CVD Name CVD Category LinkPred Score OS Event  \
# 0                  myocardial infarction          IHD          117.0      ROS
# 1                    myocardial ischemia          IHD           52.0      ROS
# 2                          heart failure           CM           48.0      IOS
# 3                  myocardial infarction          IHD           41.0      IOS
# 4          myocardial reperfusion injury          IHD           39.0      IOS
# ..                                   ...          ...            ...      ...
# 592                         cardiomegaly          OHD            1.0      IOS
# 593                     long qt syndrome          CCS            1.0      IOS
# 594        ventricular dysfunction, left          OHD            1.0      IOS
# 595                         cardiomegaly          OHD            1.0      IOS
# 596  anterior wall myocardial infarction          IHD            1.0      IOS
#
#                OS Name
# 0           isoenzymes
# 1           isoenzymes
# 2         nitric oxide
# 3         nitric oxide
# 4         nitric oxide
# ..                 ...
# 592  hydrogen peroxide
# 593  hydrogen peroxide
# 594   hydroxyl radical
# 595        superoxides
# 596  hydrogen peroxide
#
# [597 rows x 5 columns]

# %%
#df.to_csv("hello.csv", index = False)

# %% [markdown]
# ## Link Prediction with Ion Channel Proteins and MeSH Terms

# %%
#GET A LIST OF ALL Proteins

query = "MATCH (m:Protein) RETURN m.name as Name, m.id as id"
Result = []
with driver.session() as session:
    info = session.run(query)
    for item in info:
        Result.append({"Protein Name":item.values()[0],
                      "UniProt ID":item.values()[1]})

protein = pd.DataFrame(Result)
protein.reset_index(drop=True)
# Out:
#                                           Protein Name UniProt ID
# 0                         Gap junction alpha-1 protein     P17302
# 1    Voltage-dependent L-type calcium channel subun...     Q13936
# 2    Voltage-dependent T-type calcium channel subun...     O95180
# 3                     Kv channel-interacting protein 2     Q9NS61
# 4    Transient receptor potential cation channel su...     Q8TD43
# ..                                                 ...        ...
# 426                                               None     Q16515
# 427                                               None     P63252
# 428                                               None     Q9UF02
# 429                                               None     Q9H244
# 430                                               None     P25116
#
# [431 rows x 2 columns]

# %%
#USING THE MESH QUERIES FROM THE OTHER LINKPRED TABLE

class LinkPred():
    """Class to run LinkPred"""
    def __init__(self) -> None:
        self.driver = GraphDatabase.driver("neo4j://localhost:7687", auth=("neo4j", "heart"))


    def close(self) -> None:
        self.driver.close()

    @classmethod
    def LinkPred(cls, tx, name1, name2) -> any:
        """
        @param cls is the class
        @param tx is the transaction
        @return result.data() is the data of the cluster
        """
        query = ("""
        MATCH (m:MeSH {name: $name1})
        MATCH (n:Protein {id: $name2})
        RETURN gds.alpha.linkprediction.adamicAdar(n, m) AS LinkPred_Score
        """)
        result = tx.run(query, name1 = name1, name2 = name2)
        return result.data()

    def run_LinkPred(self, os, protein) -> any:
        """
        @param self
        @return result is the dataframe from the pagerank
        """
        # create empty list
        protname = []
        id = []
        linkpred = []
        os_list = []
        os_event = []
        for i in tqdm(range(len(os["OS Name"])), desc= "Iterating through df: "):
            for j in range(len(protein["UniProt ID"])):
                linkpred.append(self.driver.session().write_transaction(self.LinkPred, os["OS Name"][i], protein["UniProt ID"][j]))
                os_list.append(os["OS Name"][i])
                id.append(protein["UniProt ID"][j])
                protname.append(protein["Protein Name"][j])
                os_event.append(os["OS Event"][i])
        df = pd.DataFrame()
        df["Protein Name"] = protname
        df["UniProt ID"] = id
        df["LinkPred Score"] = linkpred
        df["OS Name"] = os_list
        df["OS Event"] = os_event
        return df

# %%
protein_mesh = LinkPred()
result = protein_mesh.run_LinkPred(OS, protein)
result
# Out:
# Iterating through df: 100%|██████████| 78/78 [02:34<00:00,  1.97s/it]
#                                             Protein Name UniProt ID  \
# 0                           Gap junction alpha-1 protein     P17302
# 1      Voltage-dependent L-type calcium channel subun...     Q13936
# 2      Voltage-dependent T-type calcium channel subun...     O95180
# 3                       Kv channel-interacting protein 2     Q9NS61
# 4      Transient receptor potential cation channel su...     Q8TD43
# ...                                                  ...        ...
# 33613                                               None     Q16515
# 33614                                               None     P63252
# 33615                                               None     Q9UF02
# 33616                                               None     Q9H244
# 33617                                               None     P25116
#
#                                  LinkPred Score         OS Name OS Event
# 0       [{'LinkPred_Score': 4.316951657079506}]     superoxides      IOS
# 1                     [{'LinkPred_Score': 0.0}]     superoxides      IOS
# 2                     [{'LinkPred_Score': 0.0}]     superoxides      IOS
# 3      [{'LinkPred_Score': 0.7213475204444817}]     superoxides      IOS
# 4                     [{'LinkPred_Score': 0.0}]     superoxides      IOS
# ...                                         ...             ...      ...
# 33613                 [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 33614                 [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 33615                 [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 33616                 [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 33617                 [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
#
# [33618 rows x 5 columns]

# %%
result = result[result['LinkPred Score'].map(lambda d: len(d)) > 0]
result = result.dropna().reset_index(drop=True)
result
# Out:
#                                             Protein Name UniProt ID  \
# 0                           Gap junction alpha-1 protein     P17302
# 1      Voltage-dependent L-type calcium channel subun...     Q13936
# 2      Voltage-dependent T-type calcium channel subun...     O95180
# 3                       Kv channel-interacting protein 2     Q9NS61
# 4      Transient receptor potential cation channel su...     Q8TD43
# ...                                                  ...        ...
# 10837                         Matrix metalloproteinase-9     P14780
# 10838  Natural resistance-associated macrophage prote...     P49281
# 10839  Leucine-rich repeat serine/threonine-protein k...     Q5S007
# 10840                          Calcium uniporter protein     S4R468
# 10841                          Calcium uniporter protein     B4DWD0
#
#                    LinkPred Score         OS Name OS Event
# 0       [{'LinkPred_Score': 5.0}]     superoxides      IOS
# 1       [{'LinkPred_Score': 0.0}]     superoxides      IOS
# 2       [{'LinkPred_Score': 0.0}]     superoxides      IOS
# 3       [{'LinkPred_Score': 1.0}]     superoxides      IOS
# 4       [{'LinkPred_Score': 0.0}]     superoxides      IOS
# ...                           ...             ...      ...
# 10837  [{'LinkPred_Score': 13.0}]  deoxyguanosine      OOS
# 10838   [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 10839   [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 10840   [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
# 10841   [{'LinkPred_Score': 0.0}]  deoxyguanosine      OOS
#
# [10842 rows x 5 columns]

# %%
for i in range(len(result["LinkPred Score"])):
    result["LinkPred Score"][i] = result["LinkPred Score"][i][0]["LinkPred_Score"]

result = result.sort_values(by = 'LinkPred Score', ascending= False)
result = result.dropna().reset_index(drop=True)
result = result[result["LinkPred Score"] > 0]
result
# Out:
#                            Protein Name UniProt ID LinkPred Score  \
# 0          Nitric oxide synthase, brain     P29475         2592.0
# 1        Amyloid-beta precursor protein     P05067         1364.0
# 2           Protein kinase C alpha type     P17252         1318.0
# 3                          Presenilin-1     P49768          985.0
# 4                            Dystrophin     P11532          670.0
# ...                                 ...        ...            ...
# 1930       Nitric oxide synthase, brain     P29475            1.0
# 1931        Protein kinase C alpha type     P17252            1.0
# 1932        Protein kinase C alpha type     P17252            1.0
# 1933                         Dystrophin     P11532            1.0
# 1934  Glutathione S-transferase omega-1     P78417            1.0
#
#                     OS Name OS Event
# 0              nitric oxide      IOS
# 1         membrane proteins      ROS
# 2                isoenzymes      ROS
# 3         membrane proteins      ROS
# 4         membrane proteins      ROS
# ...                     ...      ...
# 1930       peroxiredoxin vi      ROS
# 1931     peroxynitrous acid      IOS
# 1932  protein carbonylation      OOS
# 1933  protein carbonylation      OOS
# 1934         peroxiredoxins      ROS
#
# [1935 rows x 5 columns]

# %%
result = result.dropna()
result
# Out:
#                            Protein Name UniProt ID LinkPred Score  \
# 0          Nitric oxide synthase, brain     P29475         2592.0
# 1        Amyloid-beta precursor protein     P05067         1364.0
# 2           Protein kinase C alpha type     P17252         1318.0
# 3                          Presenilin-1     P49768          985.0
# 4                            Dystrophin     P11532          670.0
# ...                                 ...        ...            ...
# 1930       Nitric oxide synthase, brain     P29475            1.0
# 1931        Protein kinase C alpha type     P17252            1.0
# 1932        Protein kinase C alpha type     P17252            1.0
# 1933                         Dystrophin     P11532            1.0
# 1934  Glutathione S-transferase omega-1     P78417            1.0
#
#                     OS Name OS Event
# 0              nitric oxide      IOS
# 1         membrane proteins      ROS
# 2                isoenzymes      ROS
# 3         membrane proteins      ROS
# 4         membrane proteins      ROS
# ...                     ...      ...
# 1930       peroxiredoxin vi      ROS
# 1931     peroxynitrous acid      IOS
# 1932  protein carbonylation      OOS
# 1933  protein carbonylation      OOS
# 1934         peroxiredoxins      ROS
#
# [1935 rows x 5 columns]

# %%
result.to_csv("[REVISED]OS_Protein_LinkPred_commonNeighbors.csv", index = False)
